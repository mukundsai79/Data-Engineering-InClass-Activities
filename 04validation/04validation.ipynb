# %%
import pandas as pd

# %%
df = pd.read_csv('/content/Hwy26Crashes2019_S23.csv')

# %%
crash_df = df[df['Record Type'] == 1]
vehicle_df = df[df['Record Type'] == 2]
participant_df = df[df['Record Type'] == 3]

crash_df.to_csv('crash_data.csv', index = False, header=True)
vehicle_df.to_csv('vehicle_data.csv', index = False, header=True)
participant_df.to_csv('participant_data.csv', index=False, header=True)

# %%
# Existence assertions
# Load vehicle data and crash data
vehicle_data = pd.read_csv('vehicle_data.csv')
crash_data = pd.read_csv('crash_data.csv')

vehicle_crash_ids = vehicle_data['Crash ID'].unique()
crash_ids = crash_data['Crash ID'].unique()

# Check if all vehicle crash IDs are found in the crash IDs
unmatched_ids = set(vehicle_crash_ids) - set(crash_ids)
assert len(unmatched_ids) == 0, "There are vehicle records without a matching Crash ID"

print("All vehicle records have a matching Crash ID in the crash data.")
# Out:
# All vehicle records have a matching Crash ID in the crash data.

# %%
# Limit assertion
# Checking whether crash ID is of length 8
print(len(df))
df = df[df['Crash ID'].astype(str).str.len() == 7 ]
print(len(df))
# Out:
# 2739
# 2739

# %%
# Intra record assertion
# If the weather is clear, the road surface should not be icy or snowy.
incompatible_weather_road = crash_data[
    (crash_data['Weather Condition'] == 'Clear') & (crash_data['Road Surface Condition'].isin(['Icy', 'Snowy']))
]
if not incompatible_weather_road.empty:
    print("There are records with incompatible weather and road surface conditions.")
    print(incompatible_weather_road)
else:
    print("All records have compatible weather and road surface conditions.")
# Out:
# All records have compatible weather and road surface conditions.

# %%
# Inter-Record Assertion
# Every vehicle listed in the crash data was part of a known crash
unknown_crashes = set(vehicle_data['Crash ID']) - set(crash_data['Crash ID'])
if unknown_crashes:
    print(f"There are vehicles listed with crash IDs that do not match any known crash: {unknown_crashes}")
else:
    print("All vehicles are part of a known crash.")
# Vehicles which are involved in a crash but not with an object at the time of the crash
crash_data_list = []
vehicle_data_list = []
# Read data into lists using filtered DataFrames
for row in crash_df.to_dict(orient='records'):
    crash_data_list.append(row)

for row in vehicle_df.to_dict(orient='records'):
    vehicle_data_list.append(row)
crash_vehicle_ids = set([row['Vehicle ID'] for row in vehicle_data_list])

for vehicle_id in crash_vehicle_ids:
    has_collision = any([row["Crash Type"] == "8" for row in crash_data_list if row["Crash ID"] == vehicle_id])

    if vehicle_id in crash_vehicle_ids and not has_collision:
        print(f"Vehicle {vehicle_id} became involved in a crash but did not hit anything.")
# Out:
# All vehicles are part of a known crash.
# Vehicle 3483652.0 became involved in a crash but did not hit anything.
# Vehicle 3483653.0 became involved in a crash but did not hit anything.
# Vehicle 3479559.0 became involved in a crash but did not hit anything.
# Vehicle 3479560.0 became involved in a crash but did not hit anything.
# Vehicle 3461130.0 became involved in a crash but did not hit anything.
# Vehicle 3461131.0 became involved in a crash but did not hit anything.
# Vehicle 3465226.0 became involved in a crash but did not hit anything.
# Vehicle 3465227.0 became involved in a crash but did not hit anything.
# Vehicle 3489808.0 became involved in a crash but did not hit anything.
# Vehicle 3489809.0 became involved in a crash but did not hit anything.
# Vehicle 3479570.0 became involved in a crash but did not hit anything.
# Vehicle 3479571.0 became involved in a crash but did not hit anything.
# Vehicle 3479572.0 became involved in a crash but did not hit anything.
# Vehicle 3483668.0 became involved in a crash but did not hit anything.
# Vehicle 3483669.0 became involved in a crash but did not hit anything.
# Vehicle 3446808.0 became involved in a crash but did not hit anything.
# Vehicle 3446809.0 became involved in a crash but did not hit anything.
# Vehicle 3477530.0 became involved in a crash but did not hit anything.
# Vehicle 3477531.0 became involved in a crash but did not hit anything.
# Vehicle 3491872.0 became involved in a crash but did not hit anything.
# Vehicle 3491873.0 became involved in a crash but did not hit anything.
# Vehicle 3491874.0 became involved in a crash but did not hit anything.
# Vehicle 3479587.0 became involved in a crash but did not hit anything.
# Vehicle 3479588.0 became involved in a crash but did not hit anything.
# Vehicle 3495975.0 became involved in a crash but did not hit anything.
# Vehicle 3495976.0 became involved in a crash but did not hit anything.
# Vehicle 3479601.0 became involved in a crash but did not hit anything.
# Vehicle 3498037.0 became involved in a crash but did not hit anything.
# Vehicle 3498038.0 became involved in a crash but did not hit anything.
# Vehicle 3477559.0 became involved in a crash but did not hit anything.
# Vehicle 3477560.0 became involved in a crash but did not hit anything.
# Vehicle 3491895.0 became involved in a crash but did not hit anything.
# Vehicle 3473466.0 became involved in a crash but did not hit anything.
# Vehicle 3461179.0 became involved in a crash but did not hit anything.
# Vehicle 3461180.0 became involved in a crash but did not hit anything.
# Vehicle 3473467.0 became involved in a crash but did not hit anything.
# Vehicle 3473468.0 became involved in a crash but did not hit anything.
# Vehicle 3483707.0 became involved in a crash but did not hit anything.
# Vehicle 3483708.0 became involved in a crash but did not hit anything.
# Vehicle 3483710.0 became involved in a crash but did not hit anything.
# Vehicle 3483711.0 became involved in a crash but did not hit anything.
# Vehicle 3500099.0 became involved in a crash but did not hit anything.
# Vehicle 3491908.0 became involved in a crash but did not hit anything.
# Vehicle 3491909.0 became involved in a crash but did not hit anything.
# Vehicle 3491910.0 became involved in a crash but did not hit anything.
# Vehicle 3491911.0 became involved in a crash but did not hit anything.
# Vehicle 3500100.0 became involved in a crash but did not hit anything.
# Vehicle 3450955.0 became involved in a crash but did not hit anything.
# Vehicle 3450956.0 became involved in a crash but did not hit anything.
# Vehicle 3489869.0 became involved in a crash but did not hit anything.
# Vehicle 3489870.0 became involved in a crash but did not hit anything.
# Vehicle 3487825.0 became involved in a crash but did not hit anything.
# Vehicle 3489876.0 became involved in a crash but did not hit anything.
# Vehicle 3446869.0 became involved in a crash but did not hit anything.
# Vehicle 3446870.0 became involved in a crash but did not hit anything.
# Vehicle 3489877.0 became involved in a crash but did not hit anything.
# Vehicle 3487834.0 became involved in a crash but did not hit anything.
# Vehicle 3487835.0 became involved in a crash but did not hit anything.
# Vehicle 3459166.0 became involved in a crash but did not hit anything.
# Vehicle 3459167.0 became involved in a crash but did not hit anything.
# Vehicle 3491941.0 became involved in a crash but did not hit anything.
# Vehicle 3455078.0 became involved in a crash but did not hit anything.
# Vehicle 3455079.0 became involved in a crash but did not hit anything.
# Vehicle 3487851.0 became involved in a crash but did not hit anything.
# Vehicle 3500142.0 became involved in a crash but did not hit anything.
# Vehicle 3500143.0 became involved in a crash but did not hit anything.
# Vehicle 3487863.0 became involved in a crash but did not hit anything.
# Vehicle 3487864.0 became involved in a crash but did not hit anything.
# Vehicle 3491964.0 became involved in a crash but did not hit anything.
# Vehicle 3502207.0 became involved in a crash but did not hit anything.
# Vehicle 3491976.0 became involved in a crash but did not hit anything.
# Vehicle 3491977.0 became involved in a crash but did not hit anything.
# Vehicle 3491978.0 became involved in a crash but did not hit anything.
# Vehicle 3475596.0 became involved in a crash but did not hit anything.
# Vehicle 3475597.0 became involved in a crash but did not hit anything.
# Vehicle 3475598.0 became involved in a crash but did not hit anything.
# Vehicle 3471503.0 became involved in a crash but did not hit anything.
# Vehicle 3471504.0 became involved in a crash but did not hit anything.
# Vehicle 3475599.0 became involved in a crash but did not hit anything.
# Vehicle 3477647.0 became involved in a crash but did not hit anything.
# Vehicle 3477648.0 became involved in a crash but did not hit anything.
# Vehicle 3481741.0 became involved in a crash but did not hit anything.
# Vehicle 3481742.0 became involved in a crash but did not hit anything.
# Vehicle 3487889.0 became involved in a crash but did not hit anything.
# Vehicle 3487890.0 became involved in a crash but did not hit anything.
# Vehicle 3469464.0 became involved in a crash but did not hit anything.
# Vehicle 3487892.0 became involved in a crash but did not hit anything.
# Vehicle 3483802.0 became involved in a crash but did not hit anything.
# Vehicle 3483803.0 became involved in a crash but did not hit anything.
# Vehicle 3487893.0 became involved in a crash but did not hit anything.
# Vehicle 3459229.0 became involved in a crash but did not hit anything.
# Vehicle 3459230.0 became involved in a crash but did not hit anything.
# Vehicle 3494045.0 became involved in a crash but did not hit anything.
# Vehicle 3477664.0 became involved in a crash but did not hit anything.
# Vehicle 3477665.0 became involved in a crash but did not hit anything.
# Vehicle 3467426.0 became involved in a crash but did not hit anything.
# Vehicle 3453091.0 became involved in a crash but did not hit anything.
# Vehicle 3453092.0 became involved in a crash but did not hit anything.
# Vehicle 3453093.0 became involved in a crash but did not hit anything.
# Vehicle 3453094.0 became involved in a crash but did not hit anything.
# Vehicle 3467427.0 became involved in a crash but did not hit anything.
# Vehicle 3477666.0 became involved in a crash but did not hit anything.
# Vehicle 3467433.0 became involved in a crash but did not hit anything.
# Vehicle 3467434.0 became involved in a crash but did not hit anything.
# Vehicle 3467444.0 became involved in a crash but did not hit anything.
# Vehicle 3467445.0 became involved in a crash but did not hit anything.
# Vehicle 3485881.0 became involved in a crash but did not hit anything.
# Vehicle 3485882.0 became involved in a crash but did not hit anything.
# Vehicle 3489978.0 became involved in a crash but did not hit anything.
# Vehicle 3485885.0 became involved in a crash but did not hit anything.
# Vehicle 3485886.0 became involved in a crash but did not hit anything.
# Vehicle 3481795.0 became involved in a crash but did not hit anything.
# Vehicle 3481796.0 became involved in a crash but did not hit anything.
# Vehicle 3459277.0 became involved in a crash but did not hit anything.
# Vehicle 3459278.0 became involved in a crash but did not hit anything.
# Vehicle 3487956.0 became involved in a crash but did not hit anything.
# Vehicle 3487957.0 became involved in a crash but did not hit anything.
# Vehicle 3487958.0 became involved in a crash but did not hit anything.
# Vehicle 3440861.0 became involved in a crash but did not hit anything.
# Vehicle 3440862.0 became involved in a crash but did not hit anything.
# Vehicle 3442919.0 became involved in a crash but did not hit anything.
# Vehicle 3442920.0 became involved in a crash but did not hit anything.
# Vehicle 3475689.0 became involved in a crash but did not hit anything.
# Vehicle 3475690.0 became involved in a crash but did not hit anything.
# Vehicle 3475691.0 became involved in a crash but did not hit anything.
# Vehicle 3490024.0 became involved in a crash but did not hit anything.
# Vehicle 3490025.0 became involved in a crash but did not hit anything.
# Vehicle 3479794.0 became involved in a crash but did not hit anything.
# Vehicle 3467508.0 became involved in a crash but did not hit anything.
# Vehicle 3487990.0 became involved in a crash but did not hit anything.
# Vehicle 3487991.0 became involved in a crash but did not hit anything.
# Vehicle 3483898.0 became involved in a crash but did not hit anything.
# Vehicle 3483899.0 became involved in a crash but did not hit anything.
# Vehicle 3498234.0 became involved in a crash but did not hit anything.
# Vehicle 3479809.0 became involved in a crash but did not hit anything.
# Vehicle 3477762.0 became involved in a crash but did not hit anything.
# Vehicle 3477763.0 became involved in a crash but did not hit anything.
# Vehicle 3479810.0 became involved in a crash but did not hit anything.
# Vehicle 3455237.0 became involved in a crash but did not hit anything.
# Vehicle 3455238.0 became involved in a crash but did not hit anything.
# Vehicle 3471621.0 became involved in a crash but did not hit anything.
# Vehicle 3471622.0 became involved in a crash but did not hit anything.
# Vehicle 3479811.0 became involved in a crash but did not hit anything.
# Vehicle 3481864.0 became involved in a crash but did not hit anything.
# Vehicle 3481865.0 became involved in a crash but did not hit anything.
# Vehicle 3490059.0 became involved in a crash but did not hit anything.
# Vehicle 3490060.0 became involved in a crash but did not hit anything.
# Vehicle 3492102.0 became involved in a crash but did not hit anything.
# Vehicle 3492103.0 became involved in a crash but did not hit anything.
# Vehicle 3479827.0 became involved in a crash but did not hit anything.
# Vehicle 3479828.0 became involved in a crash but did not hit anything.
# Vehicle 3475739.0 became involved in a crash but did not hit anything.
# Vehicle 3475740.0 became involved in a crash but did not hit anything.
# Vehicle 3481887.0 became involved in a crash but did not hit anything.
# Vehicle 3481888.0 became involved in a crash but did not hit anything.
# Vehicle 3493004.0 became involved in a crash but did not hit anything.
# Vehicle 3477794.0 became involved in a crash but did not hit anything.
# Vehicle 3477795.0 became involved in a crash but did not hit anything.
# Vehicle 3493005.0 became involved in a crash but did not hit anything.
# Vehicle 3490095.0 became involved in a crash but did not hit anything.
# Vehicle 3477814.0 became involved in a crash but did not hit anything.
# Vehicle 3477815.0 became involved in a crash but did not hit anything.
# Vehicle 3500353.0 became involved in a crash but did not hit anything.
# Vehicle 3500354.0 became involved in a crash but did not hit anything.
# Vehicle 3483976.0 became involved in a crash but did not hit anything.
# Vehicle 3483977.0 became involved in a crash but did not hit anything.
# Vehicle 3500361.0 became involved in a crash but did not hit anything.
# Vehicle 3500362.0 became involved in a crash but did not hit anything.
# Vehicle 3486029.0 became involved in a crash but did not hit anything.
# Vehicle 3486030.0 became involved in a crash but did not hit anything.
# Vehicle 3473748.0 became involved in a crash but did not hit anything.
# Vehicle 3443029.0 became involved in a crash but did not hit anything.
# Vehicle 3443030.0 became involved in a crash but did not hit anything.
# Vehicle 3473749.0 became involved in a crash but did not hit anything.
# Vehicle 3486040.0 became involved in a crash but did not hit anything.
# Vehicle 3486041.0 became involved in a crash but did not hit anything.
# Vehicle 3492184.0 became involved in a crash but did not hit anything.
# Vehicle 3492185.0 became involved in a crash but did not hit anything.
# Vehicle 3479904.0 became involved in a crash but did not hit anything.
# Vehicle 3479905.0 became involved in a crash but did not hit anything.
# Vehicle 3479906.0 became involved in a crash but did not hit anything.
# Vehicle 3479907.0 became involved in a crash but did not hit anything.
# Vehicle 3488100.0 became involved in a crash but did not hit anything.
# Vehicle 3488101.0 became involved in a crash but did not hit anything.
# Vehicle 3492194.0 became involved in a crash but did not hit anything.
# Vehicle 3492195.0 became involved in a crash but did not hit anything.
# Vehicle 3457393.0 became involved in a crash but did not hit anything.
# Vehicle 3457394.0 became involved in a crash but did not hit anything.
# Vehicle 3469684.0 became involved in a crash but did not hit anything.
# Vehicle 3469685.0 became involved in a crash but did not hit anything.
# Vehicle 3469686.0 became involved in a crash but did not hit anything.
# Vehicle 3475829.0 became involved in a crash but did not hit anything.
# Vehicle 3475830.0 became involved in a crash but did not hit anything.
# Vehicle 3481983.0 became involved in a crash but did not hit anything.
# Vehicle 3481984.0 became involved in a crash but did not hit anything.
# Vehicle 3488127.0 became involved in a crash but did not hit anything.
# Vehicle 3443074.0 became involved in a crash but did not hit anything.
# Vehicle 3488128.0 became involved in a crash but did not hit anything.
# Vehicle 3490178.0 became involved in a crash but did not hit anything.
# Vehicle 3490179.0 became involved in a crash but did not hit anything.
# Vehicle 3490180.0 became involved in a crash but did not hit anything.
# Vehicle 3486087.0 became involved in a crash but did not hit anything.
# Vehicle 3486088.0 became involved in a crash but did not hit anything.
# Vehicle 3490181.0 became involved in a crash but did not hit anything.
# Vehicle 3490186.0 became involved in a crash but did not hit anything.
# Vehicle 3490187.0 became involved in a crash but did not hit anything.
# Vehicle 3484059.0 became involved in a crash but did not hit anything.
# Vehicle 3484060.0 became involved in a crash but did not hit anything.
# Vehicle 3473825.0 became involved in a crash but did not hit anything.
# Vehicle 3473826.0 became involved in a crash but did not hit anything.
# Vehicle 3479972.0 became involved in a crash but did not hit anything.
# Vehicle 3479973.0 became involved in a crash but did not hit anything.
# Vehicle 3479974.0 became involved in a crash but did not hit anything.
# Vehicle 3453351.0 became involved in a crash but did not hit anything.
# Vehicle 3453352.0 became involved in a crash but did not hit anything.
# Vehicle 3486121.0 became involved in a crash but did not hit anything.
# Vehicle 3486122.0 became involved in a crash but did not hit anything.
# Vehicle 3467693.0 became involved in a crash but did not hit anything.
# Vehicle 3467694.0 became involved in a crash but did not hit anything.
# Vehicle 3501580.0 became involved in a crash but did not hit anything.
# Vehicle 3501581.0 became involved in a crash but did not hit anything.
# Vehicle 3492275.0 became involved in a crash but did not hit anything.
# Vehicle 3492276.0 became involved in a crash but did not hit anything.
# Vehicle 3459511.0 became involved in a crash but did not hit anything.
# Vehicle 3459512.0 became involved in a crash but did not hit anything.
# Vehicle 3467704.0 became involved in a crash but did not hit anything.
# Vehicle 3492280.0 became involved in a crash but did not hit anything.
# Vehicle 3492281.0 became involved in a crash but did not hit anything.
# Vehicle 3490237.0 became involved in a crash but did not hit anything.
# Vehicle 3490238.0 became involved in a crash but did not hit anything.
# Vehicle 3492290.0 became involved in a crash but did not hit anything.
# Vehicle 3492291.0 became involved in a crash but did not hit anything.
# Vehicle 3486156.0 became involved in a crash but did not hit anything.
# Vehicle 3486157.0 became involved in a crash but did not hit anything.
# Vehicle 3461582.0 became involved in a crash but did not hit anything.
# Vehicle 3461583.0 became involved in a crash but did not hit anything.
# Vehicle 3500495.0 became involved in a crash but did not hit anything.
# Vehicle 3465681.0 became involved in a crash but did not hit anything.
# Vehicle 3465682.0 became involved in a crash but did not hit anything.
# Vehicle 3500496.0 became involved in a crash but did not hit anything.
# Vehicle 3490269.0 became involved in a crash but did not hit anything.
# Vehicle 3490270.0 became involved in a crash but did not hit anything.
# Vehicle 3422688.0 became involved in a crash but did not hit anything.
# Vehicle 3477990.0 became involved in a crash but did not hit anything.
# Vehicle 3477991.0 became involved in a crash but did not hit anything.
# Vehicle 3492329.0 became involved in a crash but did not hit anything.
# Vehicle 3443178.0 became involved in a crash but did not hit anything.
# Vehicle 3443179.0 became involved in a crash but did not hit anything.
# Vehicle 3469804.0 became involved in a crash but did not hit anything.
# Vehicle 3469805.0 became involved in a crash but did not hit anything.
# Vehicle 3492330.0 became involved in a crash but did not hit anything.
# Vehicle 3492339.0 became involved in a crash but did not hit anything.
# Vehicle 3492340.0 became involved in a crash but did not hit anything.
# Vehicle 3478014.0 became involved in a crash but did not hit anything.
# Vehicle 3501189.0 became involved in a crash but did not hit anything.
# Vehicle 3498499.0 became involved in a crash but did not hit anything.
# Vehicle 3498500.0 became involved in a crash but did not hit anything.
# Vehicle 3501190.0 became involved in a crash but did not hit anything.
# Vehicle 3490329.0 became involved in a crash but did not hit anything.
# Vehicle 3490330.0 became involved in a crash but did not hit anything.
# Vehicle 3502620.0 became involved in a crash but did not hit anything.
# Vehicle 3502621.0 became involved in a crash but did not hit anything.
# Vehicle 3475999.0 became involved in a crash but did not hit anything.
# Vehicle 3476000.0 became involved in a crash but did not hit anything.
# Vehicle 3478049.0 became involved in a crash but did not hit anything.
# Vehicle 3478050.0 became involved in a crash but did not hit anything.
# Vehicle 3410470.0 became involved in a crash but did not hit anything.
# Vehicle 3465768.0 became involved in a crash but did not hit anything.
# Vehicle 3467816.0 became involved in a crash but did not hit anything.
# Vehicle 3467817.0 became involved in a crash but did not hit anything.
# Vehicle 3490347.0 became involved in a crash but did not hit anything.
# Vehicle 3490348.0 became involved in a crash but did not hit anything.
# Vehicle 3488302.0 became involved in a crash but did not hit anything.
# Vehicle 3488303.0 became involved in a crash but did not hit anything.
# Vehicle 3482174.0 became involved in a crash but did not hit anything.
# Vehicle 3482175.0 became involved in a crash but did not hit anything.
# Vehicle 3500609.0 became involved in a crash but did not hit anything.
# Vehicle 3500610.0 became involved in a crash but did not hit anything.
# Vehicle 3484233.0 became involved in a crash but did not hit anything.
# Vehicle 3484234.0 became involved in a crash but did not hit anything.
# Vehicle 3486282.0 became involved in a crash but did not hit anything.
# Vehicle 3486283.0 became involved in a crash but did not hit anything.
# Vehicle 3494473.0 became involved in a crash but did not hit anything.
# Vehicle 3494474.0 became involved in a crash but did not hit anything.
# Vehicle 3465807.0 became involved in a crash but did not hit anything.
# Vehicle 3465808.0 became involved in a crash but did not hit anything.
# Vehicle 3465809.0 became involved in a crash but did not hit anything.
# Vehicle 3488335.0 became involved in a crash but did not hit anything.
# Vehicle 3486291.0 became involved in a crash but did not hit anything.
# Vehicle 3480148.0 became involved in a crash but did not hit anything.
# Vehicle 3480149.0 became involved in a crash but did not hit anything.
# Vehicle 3486292.0 became involved in a crash but did not hit anything.
# Vehicle 3486293.0 became involved in a crash but did not hit anything.
# Vehicle 3488336.0 became involved in a crash but did not hit anything.
# Vehicle 3502677.0 became involved in a crash but did not hit anything.
# Vehicle 3502678.0 became involved in a crash but did not hit anything.
# Vehicle 3488348.0 became involved in a crash but did not hit anything.
# Vehicle 3488349.0 became involved in a crash but did not hit anything.
# Vehicle 3502691.0 became involved in a crash but did not hit anything.
# Vehicle 3492459.0 became involved in a crash but did not hit anything.
# Vehicle 3492460.0 became involved in a crash but did not hit anything.
# Vehicle 3502708.0 became involved in a crash but did not hit anything.
# Vehicle 3502709.0 became involved in a crash but did not hit anything.
# Vehicle 3459706.0 became involved in a crash but did not hit anything.
# Vehicle 3455611.0 became involved in a crash but did not hit anything.
# Vehicle 3471998.0 became involved in a crash but did not hit anything.
# Vehicle 3471999.0 became involved in a crash but did not hit anything.
# Vehicle 3472000.0 became involved in a crash but did not hit anything.
# Vehicle 3472001.0 became involved in a crash but did not hit anything.
# Vehicle 3472002.0 became involved in a crash but did not hit anything.
# Vehicle 3486338.0 became involved in a crash but did not hit anything.
# Vehicle 3486339.0 became involved in a crash but did not hit anything.
# Vehicle 3486340.0 became involved in a crash but did not hit anything.
# Vehicle 3474060.0 became involved in a crash but did not hit anything.
# Vehicle 3474061.0 became involved in a crash but did not hit anything.
# Vehicle 3412622.0 became involved in a crash but did not hit anything.
# Vehicle 3455630.0 became involved in a crash but did not hit anything.
# Vehicle 3455631.0 became involved in a crash but did not hit anything.
# Vehicle 3474062.0 became involved in a crash but did not hit anything.
# Vehicle 3494540.0 became involved in a crash but did not hit anything.
# Vehicle 3484307.0 became involved in a crash but did not hit anything.
# Vehicle 3484308.0 became involved in a crash but did not hit anything.
# Vehicle 3494541.0 became involved in a crash but did not hit anything.
# Vehicle 3486362.0 became involved in a crash but did not hit anything.
# Vehicle 3486363.0 became involved in a crash but did not hit anything.
# Vehicle 3478172.0 became involved in a crash but did not hit anything.
# Vehicle 3478173.0 became involved in a crash but did not hit anything.
# Vehicle 3495930.0 became involved in a crash but did not hit anything.
# Vehicle 3488421.0 became involved in a crash but did not hit anything.
# Vehicle 3488422.0 became involved in a crash but did not hit anything.
# Vehicle 3488423.0 became involved in a crash but did not hit anything.
# Vehicle 3459771.0 became involved in a crash but did not hit anything.
# Vehicle 3459772.0 became involved in a crash but did not hit anything.
# Vehicle 3474113.0 became involved in a crash but did not hit anything.
# Vehicle 3474120.0 became involved in a crash but did not hit anything.
# Vehicle 3474121.0 became involved in a crash but did not hit anything.
# Vehicle 3486412.0 became involved in a crash but did not hit anything.
# Vehicle 3480269.0 became involved in a crash but did not hit anything.
# Vehicle 3480270.0 became involved in a crash but did not hit anything.
# Vehicle 3486413.0 became involved in a crash but did not hit anything.
# Vehicle 3486414.0 became involved in a crash but did not hit anything.
# Vehicle 3482321.0 became involved in a crash but did not hit anything.
# Vehicle 3482322.0 became involved in a crash but did not hit anything.
# Vehicle 3482323.0 became involved in a crash but did not hit anything.
# Vehicle 3472086.0 became involved in a crash but did not hit anything.
# Vehicle 3472087.0 became involved in a crash but did not hit anything.
# Vehicle 3465946.0 became involved in a crash but did not hit anything.
# Vehicle 3465947.0 became involved in a crash but did not hit anything.
# Vehicle 3465948.0 became involved in a crash but did not hit anything.
# Vehicle 3500778.0 became involved in a crash but did not hit anything.
# Vehicle 3488505.0 became involved in a crash but did not hit anything.
# Vehicle 3488506.0 became involved in a crash but did not hit anything.
# Vehicle 3486463.0 became involved in a crash but did not hit anything.
# Vehicle 3486464.0 became involved in a crash but did not hit anything.
# Vehicle 3486465.0 became involved in a crash but did not hit anything.
# Vehicle 3478280.0 became involved in a crash but did not hit anything.
# Vehicle 3478281.0 became involved in a crash but did not hit anything.
# Vehicle 3470091.0 became involved in a crash but did not hit anything.
# Vehicle 3470092.0 became involved in a crash but did not hit anything.
# Vehicle 3453707.0 became involved in a crash but did not hit anything.
# Vehicle 3468044.0 became involved in a crash but did not hit anything.
# Vehicle 3468045.0 became involved in a crash but did not hit anything.
# Vehicle 3439374.0 became involved in a crash but did not hit anything.
# Vehicle 3439375.0 became involved in a crash but did not hit anything.
# Vehicle 3459854.0 became involved in a crash but did not hit anything.
# Vehicle 3459855.0 became involved in a crash but did not hit anything.
# Vehicle 3459860.0 became involved in a crash but did not hit anything.
# Vehicle 3449621.0 became involved in a crash but did not hit anything.
# Vehicle 3449622.0 became involved in a crash but did not hit anything.
# Vehicle 3468055.0 became involved in a crash but did not hit anything.
# Vehicle 3468056.0 became involved in a crash but did not hit anything.
# Vehicle 3476241.0 became involved in a crash but did not hit anything.
# Vehicle 3476242.0 became involved in a crash but did not hit anything.
# Vehicle 3478296.0 became involved in a crash but did not hit anything.
# Vehicle 3478297.0 became involved in a crash but did not hit anything.
# Vehicle 3486491.0 became involved in a crash but did not hit anything.
# Vehicle 3486492.0 became involved in a crash but did not hit anything.
# Vehicle 3492640.0 became involved in a crash but did not hit anything.
# Vehicle 3492641.0 became involved in a crash but did not hit anything.
# Vehicle 3492642.0 became involved in a crash but did not hit anything.
# Vehicle 3468068.0 became involved in a crash but did not hit anything.
# Vehicle 3468069.0 became involved in a crash but did not hit anything.
# Vehicle 3484452.0 became involved in a crash but did not hit anything.
# Vehicle 3484453.0 became involved in a crash but did not hit anything.
# Vehicle 3488549.0 became involved in a crash but did not hit anything.
# Vehicle 3488550.0 became involved in a crash but did not hit anything.
# Vehicle 3476269.0 became involved in a crash but did not hit anything.
# Vehicle 3476270.0 became involved in a crash but did not hit anything.
# Vehicle 3443504.0 became involved in a crash but did not hit anything.
# Vehicle 3443505.0 became involved in a crash but did not hit anything.
# Vehicle 3466033.0 became involved in a crash but did not hit anything.
# Vehicle 3466034.0 became involved in a crash but did not hit anything.
# Vehicle 3466035.0 became involved in a crash but did not hit anything.
# Vehicle 3492663.0 became involved in a crash but did not hit anything.
# Vehicle 3468101.0 became involved in a crash but did not hit anything.
# Vehicle 3453766.0 became involved in a crash but did not hit anything.
# Vehicle 3453767.0 became involved in a crash but did not hit anything.
# Vehicle 3468102.0 became involved in a crash but did not hit anything.
# Vehicle 3468115.0 became involved in a crash but did not hit anything.
# Vehicle 3468116.0 became involved in a crash but did not hit anything.
# Vehicle 3468117.0 became involved in a crash but did not hit anything.
# Vehicle 3486552.0 became involved in a crash but did not hit anything.
# Vehicle 3486553.0 became involved in a crash but did not hit anything.
# Vehicle 3491896.0 became involved in a crash but did not hit anything.
# Vehicle 3449692.0 became involved in a crash but did not hit anything.
# Vehicle 3449693.0 became involved in a crash but did not hit anything.
# Vehicle 3492703.0 became involved in a crash but did not hit anything.
# Vehicle 3492704.0 became involved in a crash but did not hit anything.
# Vehicle 3468129.0 became involved in a crash but did not hit anything.
# Vehicle 3468130.0 became involved in a crash but did not hit anything.
# Vehicle 3439466.0 became involved in a crash but did not hit anything.
# Vehicle 3439467.0 became involved in a crash but did not hit anything.
# Vehicle 3466095.0 became involved in a crash but did not hit anything.
# Vehicle 3466096.0 became involved in a crash but did not hit anything.
# Vehicle 3484537.0 became involved in a crash but did not hit anything.
# Vehicle 3484538.0 became involved in a crash but did not hit anything.
# Vehicle 3486587.0 became involved in a crash but did not hit anything.
# Vehicle 3486588.0 became involved in a crash but did not hit anything.
# Vehicle 3488636.0 became involved in a crash but did not hit anything.
# Vehicle 3488637.0 became involved in a crash but did not hit anything.
# Vehicle 3486597.0 became involved in a crash but did not hit anything.
# Vehicle 3486598.0 became involved in a crash but did not hit anything.
# Vehicle 3492743.0 became involved in a crash but did not hit anything.
# Vehicle 3492744.0 became involved in a crash but did not hit anything.
# Vehicle 3492748.0 became involved in a crash but did not hit anything.
# Vehicle 3492749.0 became involved in a crash but did not hit anything.
# Vehicle 3492750.0 became involved in a crash but did not hit anything.
# Vehicle 3492751.0 became involved in a crash but did not hit anything.
# Vehicle 3492752.0 became involved in a crash but did not hit anything.
# Vehicle 3476369.0 became involved in a crash but did not hit anything.
# Vehicle 3476370.0 became involved in a crash but did not hit anything.
# Vehicle 3492753.0 became involved in a crash but did not hit anything.
# Vehicle 3490708.0 became involved in a crash but did not hit anything.
# Vehicle 3482519.0 became involved in a crash but did not hit anything.
# Vehicle 3482520.0 became involved in a crash but did not hit anything.
# Vehicle 3459998.0 became involved in a crash but did not hit anything.
# Vehicle 3459999.0 became involved in a crash but did not hit anything.
# Vehicle 3460000.0 became involved in a crash but did not hit anything.
# Vehicle 3492766.0 became involved in a crash but did not hit anything.
# Vehicle 3492767.0 became involved in a crash but did not hit anything.
# Vehicle 3486636.0 became involved in a crash but did not hit anything.
# Vehicle 3486637.0 became involved in a crash but did not hit anything.
# Vehicle 3488687.0 became involved in a crash but did not hit anything.
# Vehicle 3494832.0 became involved in a crash but did not hit anything.
# Vehicle 3494833.0 became involved in a crash but did not hit anything.
# Vehicle 3472311.0 became involved in a crash but did not hit anything.
# Vehicle 3472312.0 became involved in a crash but did not hit anything.
# Vehicle 3472313.0 became involved in a crash but did not hit anything.
# Vehicle 3484601.0 became involved in a crash but did not hit anything.
# Vehicle 3482555.0 became involved in a crash but did not hit anything.
# Vehicle 3482556.0 became involved in a crash but did not hit anything.
# Vehicle 3486653.0 became involved in a crash but did not hit anything.
# Vehicle 3486658.0 became involved in a crash but did not hit anything.
# Vehicle 3486659.0 became involved in a crash but did not hit anything.
# Vehicle 3453899.0 became involved in a crash but did not hit anything.
# Vehicle 3453900.0 became involved in a crash but did not hit anything.
# Vehicle 3478477.0 became involved in a crash but did not hit anything.
# Vehicle 3478478.0 became involved in a crash but did not hit anything.
# Vehicle 3490764.0 became involved in a crash but did not hit anything.
# Vehicle 3490765.0 became involved in a crash but did not hit anything.
# Vehicle 3490766.0 became involved in a crash but did not hit anything.
# Vehicle 3468243.0 became involved in a crash but did not hit anything.
# Vehicle 3468244.0 became involved in a crash but did not hit anything.
# Vehicle 3488730.0 became involved in a crash but did not hit anything.
# Vehicle 3488731.0 became involved in a crash but did not hit anything.
# Vehicle 3453916.0 became involved in a crash but did not hit anything.
# Vehicle 3453917.0 became involved in a crash but did not hit anything.
# Vehicle 3478499.0 became involved in a crash but did not hit anything.
# Vehicle 3478500.0 became involved in a crash but did not hit anything.
# Vehicle 3486692.0 became involved in a crash but did not hit anything.
# Vehicle 3486693.0 became involved in a crash but did not hit anything.
# Vehicle 3503077.0 became involved in a crash but did not hit anything.
# Vehicle 3503078.0 became involved in a crash but did not hit anything.
# Vehicle 3453930.0 became involved in a crash but did not hit anything.
# Vehicle 3453931.0 became involved in a crash but did not hit anything.
# Vehicle 3492842.0 became involved in a crash but did not hit anything.
# Vehicle 3492843.0 became involved in a crash but did not hit anything.
# Vehicle 3496940.0 became involved in a crash but did not hit anything.
# Vehicle 3496941.0 became involved in a crash but did not hit anything.
# Vehicle 3476466.0 became involved in a crash but did not hit anything.
# Vehicle 3476467.0 became involved in a crash but did not hit anything.
# Vehicle 3484660.0 became involved in a crash but did not hit anything.
# Vehicle 3484661.0 became involved in a crash but did not hit anything.
# Vehicle 3415030.0 became involved in a crash but did not hit anything.
# Vehicle 3415031.0 became involved in a crash but did not hit anything.
# Vehicle 3415032.0 became involved in a crash but did not hit anything.
# Vehicle 3415033.0 became involved in a crash but did not hit anything.
# Vehicle 3455994.0 became involved in a crash but did not hit anything.
# Vehicle 3455995.0 became involved in a crash but did not hit anything.
# Vehicle 3490807.0 became involved in a crash but did not hit anything.
# Vehicle 3490808.0 became involved in a crash but did not hit anything.
# Vehicle 3490809.0 became involved in a crash but did not hit anything.
# Vehicle 3492854.0 became involved in a crash but did not hit anything.
# Vehicle 3445767.0 became involved in a crash but did not hit anything.
# Vehicle 3453959.0 became involved in a crash but did not hit anything.
# Vehicle 3453960.0 became involved in a crash but did not hit anything.
# Vehicle 3480591.0 became involved in a crash but did not hit anything.
# Vehicle 3480592.0 became involved in a crash but did not hit anything.
# Vehicle 3478549.0 became involved in a crash but did not hit anything.
# Vehicle 3478550.0 became involved in a crash but did not hit anything.
# Vehicle 3478551.0 became involved in a crash but did not hit anything.
# Vehicle 3488796.0 became involved in a crash but did not hit anything.
# Vehicle 3488797.0 became involved in a crash but did not hit anything.
# Vehicle 3480608.0 became involved in a crash but did not hit anything.
# Vehicle 3480609.0 became involved in a crash but did not hit anything.
# Vehicle 3486754.0 became involved in a crash but did not hit anything.
# Vehicle 3486755.0 became involved in a crash but did not hit anything.
# Vehicle 3476516.0 became involved in a crash but did not hit anything.
# Vehicle 3476517.0 became involved in a crash but did not hit anything.
# Vehicle 3480612.0 became involved in a crash but did not hit anything.
# Vehicle 3480613.0 became involved in a crash but did not hit anything.
# Vehicle 3480614.0 became involved in a crash but did not hit anything.
# Vehicle 3503140.0 became involved in a crash but did not hit anything.
# Vehicle 3503141.0 became involved in a crash but did not hit anything.
# Vehicle 3460139.0 became involved in a crash but did not hit anything.
# Vehicle 3460140.0 became involved in a crash but did not hit anything.
# Vehicle 3453999.0 became involved in a crash but did not hit anything.
# Vehicle 3454000.0 became involved in a crash but did not hit anything.
# Vehicle 3488816.0 became involved in a crash but did not hit anything.
# Vehicle 3488817.0 became involved in a crash but did not hit anything.
# Vehicle 3462197.0 became involved in a crash but did not hit anything.
# Vehicle 3462198.0 became involved in a crash but did not hit anything.
# Vehicle 3462199.0 became involved in a crash but did not hit anything.
# Vehicle 3486776.0 became involved in a crash but did not hit anything.
# Vehicle 3486777.0 became involved in a crash but did not hit anything.
# Vehicle 3445819.0 became involved in a crash but did not hit anything.
# Vehicle 3445820.0 became involved in a crash but did not hit anything.
# Vehicle 3484732.0 became involved in a crash but did not hit anything.
# Vehicle 3484733.0 became involved in a crash but did not hit anything.
# Vehicle 3484734.0 became involved in a crash but did not hit anything.
# Vehicle 3490877.0 became involved in a crash but did not hit anything.
# Vehicle 3490878.0 became involved in a crash but did not hit anything.
# Vehicle 3488834.0 became involved in a crash but did not hit anything.
# Vehicle 3488835.0 became involved in a crash but did not hit anything.
# Vehicle 3494975.0 became involved in a crash but did not hit anything.
# Vehicle 3494976.0 became involved in a crash but did not hit anything.
# Vehicle 3462221.0 became involved in a crash but did not hit anything.
# Vehicle 3462222.0 became involved in a crash but did not hit anything.
# Vehicle 3468367.0 became involved in a crash but did not hit anything.
# Vehicle 3468366.0 became involved in a crash but did not hit anything.
# Vehicle 3468382.0 became involved in a crash but did not hit anything.
# Vehicle 3466338.0 became involved in a crash but did not hit anything.
# Vehicle 3466339.0 became involved in a crash but did not hit anything.
# Vehicle 3466340.0 became involved in a crash but did not hit anything.
# Vehicle 3480682.0 became involved in a crash but did not hit anything.
# Vehicle 3480683.0 became involved in a crash but did not hit anything.
# Vehicle 3480684.0 became involved in a crash but did not hit anything.
# Vehicle 3499117.0 became involved in a crash but did not hit anything.
# Vehicle 3499118.0 became involved in a crash but did not hit anything.
# Vehicle 3486840.0 became involved in a crash but did not hit anything.
# Vehicle 3486841.0 became involved in a crash but did not hit anything.
# Vehicle 3443834.0 became involved in a crash but did not hit anything.
# Vehicle 3443835.0 became involved in a crash but did not hit anything.
# Vehicle 3443836.0 became involved in a crash but did not hit anything.
# Vehicle 3472506.0 became involved in a crash but did not hit anything.
# Vehicle 3472507.0 became involved in a crash but did not hit anything.
# Vehicle 3490939.0 became involved in a crash but did not hit anything.
# Vehicle 3490940.0 became involved in a crash but did not hit anything.
# Vehicle 3421313.0 became involved in a crash but did not hit anything.
# Vehicle 3421314.0 became involved in a crash but did not hit anything.
# Vehicle 3445889.0 became involved in a crash but did not hit anything.
# Vehicle 3462273.0 became involved in a crash but did not hit anything.
# Vehicle 3480709.0 became involved in a crash but did not hit anything.
# Vehicle 3480710.0 became involved in a crash but did not hit anything.
# Vehicle 3480711.0 became involved in a crash but did not hit anything.
# Vehicle 3482754.0 became involved in a crash but did not hit anything.
# Vehicle 3482755.0 became involved in a crash but did not hit anything.
# Vehicle 3482756.0 became involved in a crash but did not hit anything.
# Vehicle 3460235.0 became involved in a crash but did not hit anything.
# Vehicle 3460236.0 became involved in a crash but did not hit anything.
# Vehicle 3482762.0 became involved in a crash but did not hit anything.
# Vehicle 3445902.0 became involved in a crash but did not hit anything.
# Vehicle 3445903.0 became involved in a crash but did not hit anything.
# Vehicle 3482763.0 became involved in a crash but did not hit anything.
# Vehicle 3439761.0 became involved in a crash but did not hit anything.
# Vehicle 3482764.0 became involved in a crash but did not hit anything.
# Vehicle 3482765.0 became involved in a crash but did not hit anything.
# Vehicle 3486860.0 became involved in a crash but did not hit anything.
# Vehicle 3486861.0 became involved in a crash but did not hit anything.
# Vehicle 3486868.0 became involved in a crash but did not hit anything.
# Vehicle 3486869.0 became involved in a crash but did not hit anything.
# Vehicle 3480728.0 became involved in a crash but did not hit anything.
# Vehicle 3480729.0 became involved in a crash but did not hit anything.
# Vehicle 3486870.0 became involved in a crash but did not hit anything.
# Vehicle 3490962.0 became involved in a crash but did not hit anything.
# Vehicle 3490963.0 became involved in a crash but did not hit anything.
# Vehicle 3499162.0 became involved in a crash but did not hit anything.
# Vehicle 3499163.0 became involved in a crash but did not hit anything.
# Vehicle 3503276.0 became involved in a crash but did not hit anything.
# Vehicle 3476660.0 became involved in a crash but did not hit anything.
# Vehicle 3439797.0 became involved in a crash but did not hit anything.
# Vehicle 3439798.0 became involved in a crash but did not hit anything.
# Vehicle 3439799.0 became involved in a crash but did not hit anything.
# Vehicle 3462326.0 became involved in a crash but did not hit anything.
# Vehicle 3462327.0 became involved in a crash but did not hit anything.
# Vehicle 3462328.0 became involved in a crash but did not hit anything.
# Vehicle 3454139.0 became involved in a crash but did not hit anything.
# Vehicle 3454140.0 became involved in a crash but did not hit anything.
# Vehicle 3476661.0 became involved in a crash but did not hit anything.
# Vehicle 3488956.0 became involved in a crash but did not hit anything.
# Vehicle 3488957.0 became involved in a crash but did not hit anything.
# Vehicle 3445962.0 became involved in a crash but did not hit anything.
# Vehicle 3445963.0 became involved in a crash but did not hit anything.
# Vehicle 3501262.0 became involved in a crash but did not hit anything.
# Vehicle 3501263.0 became involved in a crash but did not hit anything.
# Vehicle 3474642.0 became involved in a crash but did not hit anything.
# Vehicle 3474643.0 became involved in a crash but did not hit anything.
# Vehicle 3474644.0 became involved in a crash but did not hit anything.
# Vehicle 3456216.0 became involved in a crash but did not hit anything.
# Vehicle 3456217.0 became involved in a crash but did not hit anything.
# Vehicle 3489937.0 became involved in a crash but did not hit anything.
# Vehicle 3501273.0 became involved in a crash but did not hit anything.
# Vehicle 3501274.0 became involved in a crash but did not hit anything.
# Vehicle 3489938.0 became involved in a crash but did not hit anything.
# Vehicle 3472609.0 became involved in a crash but did not hit anything.
# Vehicle 3472610.0 became involved in a crash but did not hit anything.
# Vehicle 3456247.0 became involved in a crash but did not hit anything.
# Vehicle 3456248.0 became involved in a crash but did not hit anything.
# Vehicle 3503359.0 became involved in a crash but did not hit anything.
# Vehicle 3462400.0 became involved in a crash but did not hit anything.
# Vehicle 3503360.0 became involved in a crash but did not hit anything.
# Vehicle 3478791.0 became involved in a crash but did not hit anything.
# Vehicle 3456264.0 became involved in a crash but did not hit anything.
# Vehicle 3478792.0 became involved in a crash but did not hit anything.
# Vehicle 3493129.0 became involved in a crash but did not hit anything.
# Vehicle 3456274.0 became involved in a crash but did not hit anything.
# Vehicle 3456275.0 became involved in a crash but did not hit anything.
# Vehicle 3503378.0 became involved in a crash but did not hit anything.
# Vehicle 3503379.0 became involved in a crash but did not hit anything.
# Vehicle 3456284.0 became involved in a crash but did not hit anything.
# Vehicle 3487013.0 became involved in a crash but did not hit anything.
# Vehicle 3487014.0 became involved in a crash but did not hit anything.
# Vehicle 3456296.0 became involved in a crash but did not hit anything.
# Vehicle 3456297.0 became involved in a crash but did not hit anything.
# Vehicle 3487016.0 became involved in a crash but did not hit anything.
# Vehicle 3487017.0 became involved in a crash but did not hit anything.
# Vehicle 3472685.0 became involved in a crash but did not hit anything.
# Vehicle 3472686.0 became involved in a crash but did not hit anything.
# Vehicle 3456309.0 became involved in a crash but did not hit anything.
# Vehicle 3446070.0 became involved in a crash but did not hit anything.
# Vehicle 3446071.0 became involved in a crash but did not hit anything.
# Vehicle 3472697.0 became involved in a crash but did not hit anything.
# Vehicle 3472698.0 became involved in a crash but did not hit anything.
# Vehicle 3472699.0 became involved in a crash but did not hit anything.
# Vehicle 3474746.0 became involved in a crash but did not hit anything.
# Vehicle 3474747.0 became involved in a crash but did not hit anything.
# Vehicle 3491129.0 became involved in a crash but did not hit anything.
# Vehicle 3491130.0 became involved in a crash but did not hit anything.
# Vehicle 3495229.0 became involved in a crash but did not hit anything.
# Vehicle 3495230.0 became involved in a crash but did not hit anything.
# Vehicle 3503423.0 became involved in a crash but did not hit anything.
# Vehicle 3503424.0 became involved in a crash but did not hit anything.
# Vehicle 3480900.0 became involved in a crash but did not hit anything.
# Vehicle 3480901.0 became involved in a crash but did not hit anything.
# Vehicle 3489096.0 became involved in a crash but did not hit anything.
# Vehicle 3489097.0 became involved in a crash but did not hit anything.
# Vehicle 3489100.0 became involved in a crash but did not hit anything.
# Vehicle 3489101.0 became involved in a crash but did not hit anything.
# Vehicle 3499341.0 became involved in a crash but did not hit anything.
# Vehicle 3499342.0 became involved in a crash but did not hit anything.
# Vehicle 3472721.0 became involved in a crash but did not hit anything.
# Vehicle 3446098.0 became involved in a crash but did not hit anything.
# Vehicle 3446099.0 became involved in a crash but did not hit anything.
# Vehicle 3472722.0 became involved in a crash but did not hit anything.
# Vehicle 3472723.0 became involved in a crash but did not hit anything.
# Vehicle 3480915.0 became involved in a crash but did not hit anything.
# Vehicle 3480916.0 became involved in a crash but did not hit anything.
# Vehicle 3491160.0 became involved in a crash but did not hit anything.
# Vehicle 3491161.0 became involved in a crash but did not hit anything.
# Vehicle 3446106.0 became involved in a crash but did not hit anything.
# Vehicle 3468639.0 became involved in a crash but did not hit anything.
# Vehicle 3468640.0 became involved in a crash but did not hit anything.
# Vehicle 3489122.0 became involved in a crash but did not hit anything.
# Vehicle 3489123.0 became involved in a crash but did not hit anything.
# Vehicle 3489124.0 became involved in a crash but did not hit anything.
# ...
# Vehicle 3493394.0 became involved in a crash but did not hit anything.
# Vehicle 3460634.0 became involved in a crash but did not hit anything.
# Vehicle 3495458.0 became involved in a crash but did not hit anything.
# Vehicle 3487582.0 became involved in a crash but did not hit anything.
# Vehicle 3495459.0 became involved in a crash but did not hit anything.
# Vehicle 3466791.0 became involved in a crash but did not hit anything.
# Vehicle 3466792.0 became involved in a crash but did not hit anything.
# Vehicle 3492853.0 became involved in a crash but did not hit anything.
# Vehicle 3472940.0 became involved in a crash but did not hit anything.
# Vehicle 3472941.0 became involved in a crash but did not hit anything.
# Vehicle 3442222.0 became involved in a crash but did not hit anything.
# Vehicle 3474990.0 became involved in a crash but did not hit anything.
# Vehicle 3489329.0 became involved in a crash but did not hit anything.
# Vehicle 3489330.0 became involved in a crash but did not hit anything.
# Vehicle 3491378.0 became involved in a crash but did not hit anything.
# Vehicle 3491379.0 became involved in a crash but did not hit anything.
# Vehicle 3491384.0 became involved in a crash but did not hit anything.
# Vehicle 3442235.0 became involved in a crash but did not hit anything.
# Vehicle 3442236.0 became involved in a crash but did not hit anything.
# Vehicle 3456574.0 became involved in a crash but did not hit anything.
# Vehicle 3456575.0 became involved in a crash but did not hit anything.
# Vehicle 3495490.0 became involved in a crash but did not hit anything.
# Vehicle 3495491.0 became involved in a crash but did not hit anything.
# Vehicle 3446340.0 became involved in a crash but did not hit anything.
# Vehicle 3466822.0 became involved in a crash but did not hit anything.
# Vehicle 3468870.0 became involved in a crash but did not hit anything.
# Vehicle 3468871.0 became involved in a crash but did not hit anything.
# Vehicle 3456590.0 became involved in a crash but did not hit anything.
# Vehicle 3456591.0 became involved in a crash but did not hit anything.
# Vehicle 3470929.0 became involved in a crash but did not hit anything.
# Vehicle 3446354.0 became involved in a crash but did not hit anything.
# Vehicle 3470930.0 became involved in a crash but did not hit anything.
# Vehicle 3470931.0 became involved in a crash but did not hit anything.
# Vehicle 3456598.0 became involved in a crash but did not hit anything.
# Vehicle 3491426.0 became involved in a crash but did not hit anything.
# Vehicle 3491427.0 became involved in a crash but did not hit anything.
# Vehicle 3475051.0 became involved in a crash but did not hit anything.
# Vehicle 3475052.0 became involved in a crash but did not hit anything.
# Vehicle 3483245.0 became involved in a crash but did not hit anything.
# Vehicle 3483246.0 became involved in a crash but did not hit anything.
# Vehicle 3483247.0 became involved in a crash but did not hit anything.
# Vehicle 3493494.0 became involved in a crash but did not hit anything.
# Vehicle 3493495.0 became involved in a crash but did not hit anything.
# Vehicle 3499638.0 became involved in a crash but did not hit anything.
# Vehicle 3499639.0 became involved in a crash but did not hit anything.
# Vehicle 3444351.0 became involved in a crash but did not hit anything.
# Vehicle 3444352.0 became involved in a crash but did not hit anything.
# Vehicle 3442305.0 became involved in a crash but did not hit anything.
# Vehicle 3442306.0 became involved in a crash but did not hit anything.
# Vehicle 3487580.0 became involved in a crash but did not hit anything.
# Vehicle 3444361.0 became involved in a crash but did not hit anything.
# Vehicle 3444362.0 became involved in a crash but did not hit anything.
# Vehicle 3483275.0 became involved in a crash but did not hit anything.
# Vehicle 3483276.0 became involved in a crash but did not hit anything.
# Vehicle 3485325.0 became involved in a crash but did not hit anything.
# Vehicle 3485326.0 became involved in a crash but did not hit anything.
# Vehicle 3487581.0 became involved in a crash but did not hit anything.
# Vehicle 3468945.0 became involved in a crash but did not hit anything.
# Vehicle 3481234.0 became involved in a crash but did not hit anything.
# Vehicle 3481235.0 became involved in a crash but did not hit anything.
# Vehicle 3483282.0 became involved in a crash but did not hit anything.
# Vehicle 3483283.0 became involved in a crash but did not hit anything.
# Vehicle 3440278.0 became involved in a crash but did not hit anything.
# Vehicle 3440279.0 became involved in a crash but did not hit anything.
# Vehicle 3440280.0 became involved in a crash but did not hit anything.
# Vehicle 3440281.0 became involved in a crash but did not hit anything.
# Vehicle 3471000.0 became involved in a crash but did not hit anything.
# Vehicle 3471001.0 became involved in a crash but did not hit anything.
# Vehicle 3479200.0 became involved in a crash but did not hit anything.
# Vehicle 3479201.0 became involved in a crash but did not hit anything.
# Vehicle 3446435.0 became involved in a crash but did not hit anything.
# Vehicle 3446436.0 became involved in a crash but did not hit anything.
# Vehicle 3409578.0 became involved in a crash but did not hit anything.
# Vehicle 3409579.0 became involved in a crash but did not hit anything.
# Vehicle 3485354.0 became involved in a crash but did not hit anything.
# Vehicle 3462829.0 became involved in a crash but did not hit anything.
# Vehicle 3462830.0 became involved in a crash but did not hit anything.
# Vehicle 3473071.0 became involved in a crash but did not hit anything.
# Vehicle 3485355.0 became involved in a crash but did not hit anything.
# Vehicle 3501742.0 became involved in a crash but did not hit anything.
# Vehicle 3501743.0 became involved in a crash but did not hit anything.
# Vehicle 3446451.0 became involved in a crash but did not hit anything.
# Vehicle 3491253.0 became involved in a crash but did not hit anything.
# Vehicle 3491254.0 became involved in a crash but did not hit anything.
# Vehicle 3446464.0 became involved in a crash but did not hit anything.
# Vehicle 3475141.0 became involved in a crash but did not hit anything.
# Vehicle 3475142.0 became involved in a crash but did not hit anything.
# Vehicle 3489480.0 became involved in a crash but did not hit anything.
# Vehicle 3489481.0 became involved in a crash but did not hit anything.
# Vehicle 3473098.0 became involved in a crash but did not hit anything.
# Vehicle 3473099.0 became involved in a crash but did not hit anything.
# Vehicle 3473100.0 became involved in a crash but did not hit anything.
# Vehicle 3489482.0 became involved in a crash but did not hit anything.
# Vehicle 3483349.0 became involved in a crash but did not hit anything.
# Vehicle 3483350.0 became involved in a crash but did not hit anything.
# Vehicle 3456732.0 became involved in a crash but did not hit anything.
# Vehicle 3456733.0 became involved in a crash but did not hit anything.
# Vehicle 3493606.0 became involved in a crash but did not hit anything.
# Vehicle 3493607.0 became involved in a crash but did not hit anything.
# Vehicle 3481325.0 became involved in a crash but did not hit anything.
# Vehicle 3469038.0 became involved in a crash but did not hit anything.
# Vehicle 3469039.0 became involved in a crash but did not hit anything.
# Vehicle 3469040.0 became involved in a crash but did not hit anything.
# Vehicle 3456753.0 became involved in a crash but did not hit anything.
# Vehicle 3456754.0 became involved in a crash but did not hit anything.
# Vehicle 3481326.0 became involved in a crash but did not hit anything.
# Vehicle 3483378.0 became involved in a crash but did not hit anything.
# Vehicle 3483379.0 became involved in a crash but did not hit anything.
# Vehicle 3477239.0 became involved in a crash but did not hit anything.
# Vehicle 3477240.0 became involved in a crash but did not hit anything.
# Vehicle 3501815.0 became involved in a crash but did not hit anything.
# Vehicle 3501816.0 became involved in a crash but did not hit anything.
# Vehicle 3479295.0 became involved in a crash but did not hit anything.
# Vehicle 3479296.0 became involved in a crash but did not hit anything.
# Vehicle 3477249.0 became involved in a crash but did not hit anything.
# Vehicle 3477250.0 became involved in a crash but did not hit anything.
# Vehicle 3479297.0 became involved in a crash but did not hit anything.
# Vehicle 3493640.0 became involved in a crash but did not hit anything.
# Vehicle 3493641.0 became involved in a crash but did not hit anything.
# Vehicle 3491598.0 became involved in a crash but did not hit anything.
# Vehicle 3491599.0 became involved in a crash but did not hit anything.
# Vehicle 3493650.0 became involved in a crash but did not hit anything.
# Vehicle 3493651.0 became involved in a crash but did not hit anything.
# Vehicle 3477271.0 became involved in a crash but did not hit anything.
# Vehicle 3477272.0 became involved in a crash but did not hit anything.
# Vehicle 3452699.0 became involved in a crash but did not hit anything.
# Vehicle 3454750.0 became involved in a crash but did not hit anything.
# Vehicle 3487519.0 became involved in a crash but did not hit anything.
# Vehicle 3487545.0 became involved in a crash but did not hit anything.
# Vehicle 3475258.0 became involved in a crash but did not hit anything.
# Vehicle 3475259.0 became involved in a crash but did not hit anything.
# Vehicle 3475260.0 became involved in a crash but did not hit anything.
# Vehicle 3487546.0 became involved in a crash but did not hit anything.
# Vehicle 3489598.0 became involved in a crash but did not hit anything.
# Vehicle 3456831.0 became involved in a crash but did not hit anything.
# Vehicle 3456832.0 became involved in a crash but did not hit anything.
# Vehicle 3489599.0 became involved in a crash but did not hit anything.
# Vehicle 3491651.0 became involved in a crash but did not hit anything.
# Vehicle 3491652.0 became involved in a crash but did not hit anything.
# Vehicle 3491653.0 became involved in a crash but did not hit anything.
# Vehicle 3491657.0 became involved in a crash but did not hit anything.
# Vehicle 3483471.0 became involved in a crash but did not hit anything.
# Vehicle 3483472.0 became involved in a crash but did not hit anything.
# Vehicle 3483473.0 became involved in a crash but did not hit anything.
# Vehicle 3487571.0 became involved in a crash but did not hit anything.
# Vehicle 3487572.0 became involved in a crash but did not hit anything.
# Vehicle 3501907.0 became involved in a crash but did not hit anything.
# Vehicle 3501908.0 became involved in a crash but did not hit anything.
# Vehicle 3501912.0 became involved in a crash but did not hit anything.
# Vehicle 3501913.0 became involved in a crash but did not hit anything.
# Vehicle 3448666.0 became involved in a crash but did not hit anything.
# Vehicle 3448667.0 became involved in a crash but did not hit anything.
# Vehicle 3487578.0 became involved in a crash but did not hit anything.
# Vehicle 3475293.0 became involved in a crash but did not hit anything.
# Vehicle 3475294.0 became involved in a crash but did not hit anything.
# Vehicle 3467103.0 became involved in a crash but did not hit anything.
# Vehicle 3454816.0 became involved in a crash but did not hit anything.
# Vehicle 3454817.0 became involved in a crash but did not hit anything.
# Vehicle 3469154.0 became involved in a crash but did not hit anything.
# Vehicle 3467104.0 became involved in a crash but did not hit anything.
# Vehicle 3487579.0 became involved in a crash but did not hit anything.
# Vehicle 3409765.0 became involved in a crash but did not hit anything.
# Vehicle 3481446.0 became involved in a crash but did not hit anything.
# Vehicle 3481447.0 became involved in a crash but did not hit anything.
# Vehicle 3487592.0 became involved in a crash but did not hit anything.
# Vehicle 3487593.0 became involved in a crash but did not hit anything.
# Vehicle 3475317.0 became involved in a crash but did not hit anything.
# Vehicle 3475318.0 became involved in a crash but did not hit anything.
# Vehicle 3503992.0 became involved in a crash but did not hit anything.
# Vehicle 3503993.0 became involved in a crash but did not hit anything.
# Vehicle 3489659.0 became involved in a crash but did not hit anything.
# Vehicle 3489660.0 became involved in a crash but did not hit anything.
# Vehicle 3481471.0 became involved in a crash but did not hit anything.
# Vehicle 3481472.0 became involved in a crash but did not hit anything.
# Vehicle 3481473.0 became involved in a crash but did not hit anything.
# Vehicle 3452805.0 became involved in a crash but did not hit anything.
# Vehicle 3452806.0 became involved in a crash but did not hit anything.
# Vehicle 3479429.0 became involved in a crash but did not hit anything.
# Vehicle 3479430.0 became involved in a crash but did not hit anything.
# Vehicle 3487623.0 became involved in a crash but did not hit anything.
# Vehicle 3487624.0 became involved in a crash but did not hit anything.
# Vehicle 3479442.0 became involved in a crash but did not hit anything.
# Vehicle 3479443.0 became involved in a crash but did not hit anything.
# Vehicle 3481494.0 became involved in a crash but did not hit anything.
# Vehicle 3481495.0 became involved in a crash but did not hit anything.
# Vehicle 3479451.0 became involved in a crash but did not hit anything.
# Vehicle 3479452.0 became involved in a crash but did not hit anything.
# Vehicle 3477417.0 became involved in a crash but did not hit anything.
# Vehicle 3477418.0 became involved in a crash but did not hit anything.
# Vehicle 3467180.0 became involved in a crash but did not hit anything.
# Vehicle 3491762.0 became involved in a crash but did not hit anything.
# Vehicle 3491763.0 became involved in a crash but did not hit anything.
# Vehicle 3446710.0 became involved in a crash but did not hit anything.
# Vehicle 3489723.0 became involved in a crash but did not hit anything.
# Vehicle 3487676.0 became involved in a crash but did not hit anything.
# Vehicle 3487677.0 became involved in a crash but did not hit anything.
# Vehicle 3487678.0 became involved in a crash but did not hit anything.
# Vehicle 3493823.0 became involved in a crash but did not hit anything.
# Vehicle 3479488.0 became involved in a crash but did not hit anything.
# Vehicle 3479489.0 became involved in a crash but did not hit anything.
# Vehicle 3493824.0 became involved in a crash but did not hit anything.
# Vehicle 3497927.0 became involved in a crash but did not hit anything.
# Vehicle 3497928.0 became involved in a crash but did not hit anything.
# Vehicle 3493838.0 became involved in a crash but did not hit anything.
# Vehicle 3493839.0 became involved in a crash but did not hit anything.
# Vehicle 3440599.0 became involved in a crash but did not hit anything.
# Vehicle 3440600.0 became involved in a crash but did not hit anything.
# Vehicle 3491804.0 became involved in a crash but did not hit anything.
# Vehicle 3456989.0 became involved in a crash but did not hit anything.
# Vehicle 3456990.0 became involved in a crash but did not hit anything.
# Vehicle 3491805.0 became involved in a crash but did not hit anything.
# Vehicle 3467237.0 became involved in a crash but did not hit anything.
# Vehicle 3467238.0 became involved in a crash but did not hit anything.
# Vehicle 3479530.0 became involved in a crash but did not hit anything.
# Vehicle 3479531.0 became involved in a crash but did not hit anything.
# Vehicle 3450860.0 became involved in a crash but did not hit anything.
# Vehicle 3450861.0 became involved in a crash but did not hit anything.
# Vehicle 3497968.0 became involved in a crash but did not hit anything.
# Vehicle 3497969.0 became involved in a crash but did not hit anything.
# Vehicle 3479542.0 became involved in a crash but did not hit anything.
# Vehicle 3479543.0 became involved in a crash but did not hit anything.
# Vehicle 3479544.0 became involved in a crash but did not hit anything.
# Vehicle 3457017.0 became involved in a crash but did not hit anything.
# Vehicle 3457018.0 became involved in a crash but did not hit anything.
# Vehicle 3495931.0 became involved in a crash but did not hit anything.

# %%
# Inter record Assertion
# For each Crash ID, there will be at least two different types of records associated with it.

record_dict = {}
for index, row in df.iterrows():
    crash_id = row['Crash ID']
    str_crash_id = str(crash_id)
    record_type = row['Record Type']
    if str_crash_id not in record_dict:
        record_dict[str_crash_id] = []
    if record_type == 1:
        key = '%s-%s' % (crash_id, record_type)
        if key not in record_dict[str_crash_id]:
            record_dict[str_crash_id].append(key)
        else:
            print("duplicated key ", key)
    elif record_type == 2:
        vehicle_id = row['Vehicle ID']
        key = '%s-%s' % (crash_id, vehicle_id)
        if key not in record_dict[str_crash_id]:
            record_dict[str_crash_id].append(key)
        else:
            print("duplicated key ", key)
    elif record_type == 3:
        participant_id = row['Participant ID']
        key = '%s-%s' % (crash_id, participant_id)
        if key not in record_dict[str_crash_id]:
            record_dict[str_crash_id].append(key)
        else:
            print("duplicated key ", key)

# %%
# Summary Assertion
# Crashes at intersections and on straight roadways constitute the majority of incidents suggesting these common road configurations are critical areas for traffic safety.

intersection_crashes = df[df['Road Character'] == 1]
straight_roadway_crashes = df[df['Road Character'] == 3]

total_targeted_crashes = len(intersection_crashes) + len(straight_roadway_crashes)

total_crashes = len(df)

percentage_targeted_crashes = (total_targeted_crashes / total_crashes) * 100

# Output results
print(f"Percentage of crashes at intersections and straight roadways: {percentage_targeted_crashes:.2f}%")

# Assertion output
if percentage_targeted_crashes > 50:
    print("Most accidents happen at intersections and on roads that go straight.")
else:
    print("At intersections or on straight roads, accidents happen much less often than other places..")
# Out:
# Percentage of crashes at intersections and straight roadways: 9.49%
# At intersections or on straight roads, accidents happen much less often than other places..

# %%
# Summary assertion
# CrashId is unique across all the records
crash_id = set()
print(len(df))
for index, row in df.iterrows():
    if row['Record Type'] == 1:
        if row['Crash ID'] in crash_id:
            print("Crash ID is repeated ", index, row['Crash ID'])
            df.drop(index, inplace=True)
        else:
            crash_id.add(row['Crash ID'])
print(len(df))
# Out:
# 2739
# 2739

# %%
# Summary assertion
# There were thousands of crashes but not millions
if(len(crash_df['Crash ID']) < 1000000):
    print("There are thousands of crashes not millions");
else:
    print("There are millions of crashes");
# Out:
# There are thousands of crashes not millions

# %%
# Statistical Assertion
# Crashes are more during the middle of the day (office hours)
df = df[df['Crash Hour'] <= 24]
df.plot.scatter(x='Crash Hour', y='Crash Day', c='green')
# Out:
# <Axes: xlabel='Crash Hour', ylabel='Crash Day'>

# %%
# Statistical Assertion
# For a majority of accidents, most injuries usually fall under the minor injury category.

injury_columns = ['Total Suspected Serious Injury (A) Count',
                     'Total Suspected Minor Injury (B) Count',
                     'Total Possible Injury (C) Count']

total_injuries = crash_df[injury_columns].sum(axis=1)

injury_percentages = df[injury_columns].divide(total_injuries, axis=0).mul(100).round(2)

min_injury_percentage = injury_percentages.iloc[:, 1].mean()

if min_injury_percentage > injury_percentages.iloc[:, [0, 2]].mean(axis=1).mean():
  print("Most of the time, the injuries from accidents are not major ones.")
else:
  print("The injuries for majority of accidents doesn't fall under minor injury.")
# Out:
# Most of the time, the injuries from accidents are not major ones.

# %%
# Statistical assertion
# Less than 5% of crash participants have a suspended, revoked, or otherwise non-valid driving license  suggesting that the majority of drivers involved in crashes have valid licenses
non_valid_license_count = participant_df['Driver License Status'].isin(['3', '4', '8']).sum()
total_participants = len(participant_df)
percentage_non_valid = (non_valid_license_count / total_participants) * 100

print(f"Percentage of participants with non-valid licenses: {percentage_non_valid:.2f}%")

if percentage_non_valid < 5:
    print("Less than 5% of participants have non-valid driving licenses.")
else:
    print("More than 5% of participants have non-valid driving licenses.")
# Out:
# Percentage of participants with non-valid licenses: 0.00%
# Less than 5% of participants have non-valid driving licenses.
